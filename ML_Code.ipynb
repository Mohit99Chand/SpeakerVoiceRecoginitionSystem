# %% [markdown]
# <h1><b>LIBRARIES</h1>

# %%
import os
import wave
#import librosa
import shutil
import numpy as np
import tensorflow as tf
from tensorflow import keras
from pathlib import Path
from IPython.display import display, Audio

# %% [markdown]
# <h1><b>VALUE ASSIGNMENT</h1>

# %%
VALID_SPLIT = 0.1
SHUFFLE_SEED = 43
SAMPLING_RATE = 16000
BATCH_SIZE = 7
EPOCHS = 25

# %% [markdown]
# <h1><b>CREATING AND STORING IN FOLDERS</h1>

# %%
C_SUBF_N = "Clean"
N_SUBF_N = "Noise"

FOLD = os.path.join(os.path.expanduser("~"), r"C:\Users\Mohit Chand\Desktop\Git\SVR\finale\raw_audio")
C_SUBF = os.path.join(FOLD, C_SUBF_N)
N_SUBF = os.path.join(FOLD, N_SUBF_N)

print(FOLD)
print(C_SUBF)
print(N_SUBF)


if os.path.exists(C_SUBF) is False:
    os.makedirs(C_SUBF)


if os.path.exists(N_SUBF) is False:
    os.makedirs(N_SUBF)

for folder in os.listdir(FOLD):
    if os.path.isdir(os.path.join(FOLD, folder)):
        if folder in [C_SUBF_N, N_SUBF_N]:
            continue
        elif folder in ["other", "_background_noise_"]:
            shutil.move(
                os.path.join(FOLD, folder),
                os.path.join(N_SUBF, folder),
            )
        else:
            shutil.move(
                os.path.join(FOLD, folder),
                os.path.join(C_SUBF, folder),
            )
# Out:
# C:\Users\Mohit Chand\Desktop\Git\SVR\finale\raw_audio
# C:\Users\Mohit Chand\Desktop\Git\SVR\finale\raw_audio\Clean
# C:\Users\Mohit Chand\Desktop\Git\SVR\finale\raw_audio\Noise

# %% [markdown]
# <h1><b>DOWNSAMPLING FROM 24 BITS TO 16 BITS </h1>

# %%
def convert_and_save_audio(root_folder):
    for subfolder in os.listdir(root_folder):
        subfolder_path = os.path.join(root_folder, subfolder)
        for file in os.listdir(subfolder_path):
            if file.endswith('.wav'):
                audio_file_path = os.path.join(subfolder_path, file)
                with wave.open(audio_file_path, 'rb') as audio_file:
                    num_frames = audio_file.getnframes()
                    sample_width = audio_file.getsampwidth()
                    num_channels = audio_file.getnchannels()
                    frame_rate = audio_file.getframerate()
                    parameters = audio_file.getparams()

                    frames = audio_file.readframes(-1)

                    sample_size = num_frames * sample_width * num_channels

                    aud_new = wave.open(os.path.join(subfolder_path, file), "wb")
                    aud_new.setnchannels(2)
                    aud_new.setsampwidth(2)
                    aud_new.setframerate(16000.0)

                    aud_new.writeframes(frames)

                    aud_new.close()


if __name__ == "__main__":
    root_folder = r"C:\Users\Mohit Chand\Desktop\Git\SVR\finale\raw_audio\Clean"
    convert_and_save_audio(root_folder)

# %% [markdown]
# <h1><b>FEATURE EXTRACTION</h1>

# %%
def paths_and_labels_to_dataset(audio_paths, labels):
    path_ds = tf.data.Dataset.from_tensor_slices(audio_paths) 
    audio_ds = path_ds.map(lambda x: path_to_audio(x))
    label_ds = tf.data.Dataset.from_tensor_slices(labels)
    return tf.data.Dataset.zip((audio_ds, label_ds))


def path_to_audio(path):
  audio = tf.io.read_file(path)
  audio, _ = tf.audio.decode_wav(audio, 1, SAMPLING_RATE)
  return audio


def audio_to_fft(audio):
  audio = tf.squeeze(audio, axis=-1)
  fft = tf.signal.fft(
      tf.cast(tf.complex(real=audio, imag=tf.zeros_like(audio)), tf.complex64)
      )
  fft = tf.expand_dims(fft, axis=-1)
  return tf.math.abs(fft[:, : (audio.shape[1] // 2), :])




class_names = os.listdir(C_SUBF)
print("Our class names: {}".format(class_names,))
audio_paths = []
labels = []
for label, name in enumerate(class_names):
    print("Processing speaker {}".format(name,))
    dir_path = Path(C_SUBF) / name
    speaker_sample_paths = [
        os.path.join(dir_path, filepath)
        for filepath in os.listdir(dir_path)
        if filepath.endswith(".wav")
    ]
    audio_paths += speaker_sample_paths
    labels += [label] * len(speaker_sample_paths)

print(
    "Found {} files belonging to {} classes.".format(len(audio_paths), len(class_names))
)
# Out:
# Our class names: ['Abhay', 'Arjun', 'Chandsi', 'Kajal', 'Mohit', 'Neha_voice', 'Rutuja_voice']
# Processing speaker Abhay
# Processing speaker Arjun
# Processing speaker Chandsi
# Processing speaker Kajal
# Processing speaker Mohit
# Processing speaker Neha_voice
# Processing speaker Rutuja_voice
# Found 70 files belonging to 7 classes.

# %% [markdown]
# <h1><b>TRAINING</h1>

# %%
rng = np.random.RandomState(SHUFFLE_SEED)
rng.shuffle(audio_paths)
rng = np.random.RandomState(SHUFFLE_SEED)
rng.shuffle(labels)


num_val_samples = int(VALID_SPLIT * len(audio_paths))
print("Using {} files for training.".format(len(audio_paths) - num_val_samples))
train_audio_paths = audio_paths[:-num_val_samples]
train_labels = labels[:-num_val_samples]

print("Using {} files for validation.".format(num_val_samples))
valid_audio_paths = audio_paths[-num_val_samples:]
valid_labels = labels[-num_val_samples:]


train_ds = paths_and_labels_to_dataset(train_audio_paths, train_labels)
train_ds = train_ds.shuffle(buffer_size=BATCH_SIZE * 8, seed=SHUFFLE_SEED).batch(
    BATCH_SIZE
)

valid_ds = paths_and_labels_to_dataset(valid_audio_paths, valid_labels)
valid_ds = valid_ds.shuffle(buffer_size=32 * 8, seed=SHUFFLE_SEED).batch(32)


train_ds = train_ds.map(
      lambda x, y: (audio_to_fft(x), y), num_parallel_calls=tf.data.AUTOTUNE
)
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)

valid_ds = valid_ds.map(
    lambda x, y: (audio_to_fft(x), y), num_parallel_calls=tf.data.AUTOTUNE
)
valid_ds = valid_ds.prefetch(tf.data.AUTOTUNE)
# Out:
# Using 63 files for training.
# Using 7 files for validation.

# %% [markdown]
# <h1><b>MODEL</h1>

# %%
def residual_block(x, filters, conv_num=3, activation="relu"):
    s = keras.layers.Conv1D(filters, 1, padding="same")(x)
    for i in range(conv_num - 1):
        x = keras.layers.Conv1D(filters, 3, padding="same")(x)
        x = keras.layers.Activation(activation)(x)
    x = keras.layers.Conv1D(filters, 3, padding="same")(x)
    x = keras.layers.Add()([x, s])
    x = keras.layers.Activation(activation)(x)
    return keras.layers.MaxPool1D(pool_size=2, strides=2)(x)


def build_model(input_shape, num_classes):
    inputs = keras.layers.Input(shape=input_shape, name="input")

    x = residual_block(inputs, 16, 2)
    x = residual_block(x, 32, 2)
    x = residual_block(x, 64, 3)
    x = residual_block(x, 128, 3)
    #x = residual_block(x, 128, 3)

    x = keras.layers.AveragePooling1D(pool_size=3, strides=3)(x)
    x = keras.layers.Flatten()(x)
    x = keras.layers.Dense(256, activation="relu")(x)
    x = keras.layers.Dense(128, activation="relu")(x)

    outputs = keras.layers.Dense(num_classes, activation="softmax", name="output")(x)

    return keras.models.Model(inputs=inputs, outputs=outputs)


model = build_model((SAMPLING_RATE // 2, 1), len(class_names))

model.summary()


model.compile(
    optimizer="Adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"]
)
model_save_filename = "SVR.h5"

earlystopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
mdlcheckpoint_cb = keras.callbacks.ModelCheckpoint(
    model_save_filename, monitor="val_accuracy", save_best_only=True
)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input (InputLayer)          [(None, 8000, 1)]            0         []
#
#  conv1d_15 (Conv1D)          (None, 8000, 16)             64        ['input[0][0]']
#
#  activation_10 (Activation)  (None, 8000, 16)             0         ['conv1d_15[0][0]']
#
#  conv1d_16 (Conv1D)          (None, 8000, 16)             784       ['activation_10[0][0]']
#
#  conv1d_14 (Conv1D)          (None, 8000, 16)             32        ['input[0][0]']
#
#  add_4 (Add)                 (None, 8000, 16)             0         ['conv1d_16[0][0]',
#                                                                      'conv1d_14[0][0]']
#
#  activation_11 (Activation)  (None, 8000, 16)             0         ['add_4[0][0]']
#
#  max_pooling1d_4 (MaxPoolin  (None, 4000, 16)             0         ['activation_11[0][0]']
#  g1D)
#
#  conv1d_18 (Conv1D)          (None, 4000, 32)             1568      ['max_pooling1d_4[0][0]']
#
#  activation_12 (Activation)  (None, 4000, 32)             0         ['conv1d_18[0][0]']
#
#  conv1d_19 (Conv1D)          (None, 4000, 32)             3104      ['activation_12[0][0]']
#
#  conv1d_17 (Conv1D)          (None, 4000, 32)             544       ['max_pooling1d_4[0][0]']
#
#  add_5 (Add)                 (None, 4000, 32)             0         ['conv1d_19[0][0]',
#                                                                      'conv1d_17[0][0]']
#
#  activation_13 (Activation)  (None, 4000, 32)             0         ['add_5[0][0]']
#
#  max_pooling1d_5 (MaxPoolin  (None, 2000, 32)             0         ['activation_13[0][0]']
#  g1D)
#
#  conv1d_21 (Conv1D)          (None, 2000, 64)             6208      ['max_pooling1d_5[0][0]']
#
#  activation_14 (Activation)  (None, 2000, 64)             0         ['conv1d_21[0][0]']
#
#  conv1d_22 (Conv1D)          (None, 2000, 64)             12352     ['activation_14[0][0]']
#
#  activation_15 (Activation)  (None, 2000, 64)             0         ['conv1d_22[0][0]']
#
#  conv1d_23 (Conv1D)          (None, 2000, 64)             12352     ['activation_15[0][0]']
#
#  conv1d_20 (Conv1D)          (None, 2000, 64)             2112      ['max_pooling1d_5[0][0]']
#
#  add_6 (Add)                 (None, 2000, 64)             0         ['conv1d_23[0][0]',
#                                                                      'conv1d_20[0][0]']
#
#  activation_16 (Activation)  (None, 2000, 64)             0         ['add_6[0][0]']
#
#  max_pooling1d_6 (MaxPoolin  (None, 1000, 64)             0         ['activation_16[0][0]']
#  g1D)
#
#  conv1d_25 (Conv1D)          (None, 1000, 128)            24704     ['max_pooling1d_6[0][0]']
#
#  activation_17 (Activation)  (None, 1000, 128)            0         ['conv1d_25[0][0]']
#
#  conv1d_26 (Conv1D)          (None, 1000, 128)            49280     ['activation_17[0][0]']
#
#  activation_18 (Activation)  (None, 1000, 128)            0         ['conv1d_26[0][0]']
#
#  conv1d_27 (Conv1D)          (None, 1000, 128)            49280     ['activation_18[0][0]']
#
#  conv1d_24 (Conv1D)          (None, 1000, 128)            8320      ['max_pooling1d_6[0][0]']
#
#  add_7 (Add)                 (None, 1000, 128)            0         ['conv1d_27[0][0]',
#                                                                      'conv1d_24[0][0]']
#
#  activation_19 (Activation)  (None, 1000, 128)            0         ['add_7[0][0]']
#
#  max_pooling1d_7 (MaxPoolin  (None, 500, 128)             0         ['activation_19[0][0]']
#  g1D)
#
#  average_pooling1d_1 (Avera  (None, 166, 128)             0         ['max_pooling1d_7[0][0]']
#  gePooling1D)
#
#  flatten_1 (Flatten)         (None, 21248)                0         ['average_pooling1d_1[0][0]']
#
#  dense_2 (Dense)             (None, 256)                  5439744   ['flatten_1[0][0]']
#
#  dense_3 (Dense)             (None, 128)                  32896     ['dense_2[0][0]']
#
#  output (Dense)              (None, 7)                    903       ['dense_3[0][0]']
#
# ==================================================================================================
# Total params: 5644247 (21.53 MB)
# Trainable params: 5644247 (21.53 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# <h1><b>FIT TRAINING</h1>

# %%
history = model.fit(
    train_ds,
    epochs=EPOCHS,
    validation_data=valid_ds,
    callbacks=[earlystopping_cb, mdlcheckpoint_cb],
)
# Out:
# Epoch 1/25
# 9/9 [==============================] - 12s 591ms/step - loss: 5.0061 - accuracy: 0.3016 - val_loss: 1.3667 - val_accuracy: 0.2857
# Epoch 2/25
# 9/9 [==============================] - 5s 508ms/step - loss: 1.2992 - accuracy: 0.4921 - val_loss: 1.0835 - val_accuracy: 0.5714
# Epoch 3/25
# 9/9 [==============================] - 5s 463ms/step - loss: 0.9089 - accuracy: 0.6825 - val_loss: 0.7702 - val_accuracy: 0.5714
# Epoch 4/25
# 9/9 [==============================] - 5s 494ms/step - loss: 0.7826 - accuracy: 0.6825 - val_loss: 0.5740 - val_accuracy: 0.8571
# Epoch 5/25
# 9/9 [==============================] - 5s 476ms/step - loss: 0.6399 - accuracy: 0.7460 - val_loss: 0.6548 - val_accuracy: 0.5714
# Epoch 6/25
# 9/9 [==============================] - 7s 711ms/step - loss: 0.4724 - accuracy: 0.7937 - val_loss: 0.6503 - val_accuracy: 0.8571
# Epoch 7/25
# 9/9 [==============================] - 6s 527ms/step - loss: 0.3667 - accuracy: 0.8571 - val_loss: 0.5135 - val_accuracy: 0.8571
# Epoch 8/25
# 9/9 [==============================] - 5s 468ms/step - loss: 0.3711 - accuracy: 0.8413 - val_loss: 0.5591 - val_accuracy: 0.8571
# Epoch 9/25
# 9/9 [==============================] - 6s 611ms/step - loss: 0.2951 - accuracy: 0.9048 - val_loss: 0.2918 - val_accuracy: 1.0000
# Epoch 10/25
# 9/9 [==============================] - 6s 523ms/step - loss: 0.3084 - accuracy: 0.8730 - val_loss: 0.4368 - val_accuracy: 0.8571
# Epoch 11/25
# 9/9 [==============================] - 6s 530ms/step - loss: 0.3689 - accuracy: 0.8571 - val_loss: 0.5193 - val_accuracy: 0.8571
# Epoch 12/25
# 9/9 [==============================] - 6s 509ms/step - loss: 0.3089 - accuracy: 0.9048 - val_loss: 0.5054 - val_accuracy: 0.8571
# Epoch 13/25
# 9/9 [==============================] - 6s 512ms/step - loss: 0.2517 - accuracy: 0.9048 - val_loss: 0.4500 - val_accuracy: 0.8571
# Epoch 14/25
# 9/9 [==============================] - 6s 528ms/step - loss: 0.2109 - accuracy: 0.9365 - val_loss: 0.5839 - val_accuracy: 0.8571
# Epoch 15/25
# 9/9 [==============================] - 6s 541ms/step - loss: 0.1779 - accuracy: 0.9206 - val_loss: 0.4590 - val_accuracy: 0.8571
# Epoch 16/25
# 9/9 [==============================] - 6s 521ms/step - loss: 0.1915 - accuracy: 0.9365 - val_loss: 0.2857 - val_accuracy: 0.8571
# Epoch 17/25
# 9/9 [==============================] - 6s 566ms/step - loss: 0.1762 - accuracy: 0.9365 - val_loss: 0.6167 - val_accuracy: 0.8571
# Epoch 18/25
# 9/9 [==============================] - 6s 627ms/step - loss: 0.1313 - accuracy: 0.9365 - val_loss: 0.8263 - val_accuracy: 0.8571
# Epoch 19/25
# 9/9 [==============================] - 6s 516ms/step - loss: 0.1121 - accuracy: 0.9683 - val_loss: 0.7662 - val_accuracy: 0.8571
# Epoch 20/25
# 9/9 [==============================] - 7s 752ms/step - loss: 0.0979 - accuracy: 0.9841 - val_loss: 1.1783 - val_accuracy: 0.8571
# Epoch 21/25
# 9/9 [==============================] - 8s 793ms/step - loss: 0.4555 - accuracy: 0.9048 - val_loss: 1.0152 - val_accuracy: 0.7143
# Epoch 22/25
# 9/9 [==============================] - 9s 758ms/step - loss: 1.8872 - accuracy: 0.7460 - val_loss: 1.5390 - val_accuracy: 0.4286
# Epoch 23/25
# 9/9 [==============================] - 6s 566ms/step - loss: 0.9926 - accuracy: 0.7460 - val_loss: 0.2999 - val_accuracy: 1.0000
# Epoch 24/25
# 9/9 [==============================] - 6s 571ms/step - loss: 0.5912 - accuracy: 0.8413 - val_loss: 0.4323 - val_accuracy: 0.8571
# Epoch 25/25
# 9/9 [==============================] - 6s 530ms/step - loss: 0.3926 - accuracy: 0.8730 - val_loss: 0.2683 - val_accuracy: 0.8571

# %% [markdown]
# <h1><b>CROSS VALIDATION</h1>

# %%
print(model.evaluate(valid_ds))
# Out:
# 1/1 [==============================] - 0s 347ms/step - loss: 0.2683 - accuracy: 0.8571
# [0.26828733086586, 0.8571428656578064]

# %% [markdown]
# <h1><b>TESTING</h1>

# %%
SAMPLES_TO_DISPLAY = 7

test_ds = paths_and_labels_to_dataset(valid_audio_paths, valid_labels)
test_ds = test_ds.shuffle(buffer_size=BATCH_SIZE * 8, seed=SHUFFLE_SEED).batch(
    BATCH_SIZE
)

for audios, labels in test_ds.take(1):
   
    ffts = audio_to_fft(audios)
    y_pred = model.predict(ffts)
    
    rnd = np.random.randint(0, BATCH_SIZE, SAMPLES_TO_DISPLAY)
    audios = audios.numpy()[rnd, :, :]
    labels = labels.numpy()[rnd]
    y_pred = np.argmax(y_pred, axis=-1)[rnd]

    for index in range(SAMPLES_TO_DISPLAY):
       
        print(
            "Speaker:\33{} {}\33[0m\tPredicted:\33{} {}\33[0m".format(
                "[92m" if labels[index] == y_pred[index] else "[91m",
                class_names[labels[index]],
                "[92m" if labels[index] == y_pred[index] else "[91m",
                class_names[y_pred[index]],
            )
        )
        display(Audio(audios[index, :, :].squeeze(), rate=SAMPLING_RATE))
# Out:
# 1/1 [==============================] - 1s 901ms/step
# Speaker: Chandsi	Predicted: Chandsi
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Arjun	Predicted: Abhay
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Rutuja_voice	Predicted: Rutuja_voice
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Neha_voice	Predicted: Neha_voice
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Neha_voice	Predicted: Neha_voice
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Neha_voice	Predicted: Neha_voice
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Mohit	Predicted: Mohit
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
